# %%
"""
Making a mini COCO dataset from the full COCO dataset with balanced classes
"""

import json
from pathlib import Path
from collections import defaultdict
import random

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
def make_coco_mini_balanced(ann_path: Path, out_path: Path, images_per_class: int = 250,
                            random_seed: int = 42,):
    """
    Create a mini COCO dataset with balanced classes.

    Args:
        ann_path: Path to original COCO annotation file
        out_path: Path to save mini COCO annotation file
        images_per_class: Number of images per category (default 250)
        random_seed: Random seed for reproducibility
    """
    random.seed(random_seed)

    # Load original annotations
    ann = json.loads(ann_path.read_text())
    images = ann["images"]
    annotations = ann["annotations"]
    categories = ann["categories"]

    # Create mappings for easier lookup
    image_dict = {img["id"]: img for img in images}
    category_dict = {cat["id"]: cat for cat in categories}

    # Group annotations by image_id and category_id
    image_annotations = defaultdict(lambda: defaultdict(list))
    image_categories = defaultdict(set) # image_id -> set of category_ids

    for ann in annotations:
        img_id = ann["image_id"]
        cat_id = ann["category_id"]
        image_annotations[img_id][cat_id].append(ann)
        image_categories[img_id].add(cat_id)

    # Count images per category
    category_image_counts = defaultdict(set) # category_id -> set of image_ids

    for img_id, cats in image_categories.items():
        for cat_id in cats:
            category_image_counts[cat_id].add(img_id)

    # Print initial statistics
    print("Original dataset statistics:")
    print(f"Total images: {len(images)}")
    print(f"Total categories: {len(categories)}")
    for cat_id, img_ids in sorted(category_image_counts.items()):
        cat_name = category_dict[cat_id]["name"]
        print(f"  Category {cat_id} ({cat_name}): {len(img_ids)} images")

    # Select balanced set of images
    selected_image_ids = set()

    # For each category, select images_per_class images
    for cat_id in sorted(category_dict.keys()):
        cat_name = category_dict[cat_id]["name"]
        available_images = list(category_image_counts[cat_id])

        if len(available_images) < images_per_class:
            print(f"Warning: Category {cat_id} ({cat_name}) has only {len(available_images)} images, "
                  f"requested {images_per_class}. Using all available.")
            selected_for_cat = available_images
        else:
            # Randomly select images for this category
            selected_for_cat = random.sample(available_images, images_per_class)

        selected_image_ids.update(selected_for_cat)
        print(f"Selected {len(selected_for_cat)} images for category {cat_id} ({cat_name})")

    # Convert to list and shuffle
    selected_image_ids = list(selected_image_ids)
    random.shuffle(selected_image_ids)

    # Limit to exactly images_per_class * num_categories if we have more
    max_images = images_per_class * len(categories)
    if len(selected_image_ids) > max_images:
        print(f"Note: Selected {len(selected_image_ids)} unique images, "
              f"keeping first {max_images} to maintain balance.")
        selected_image_ids = selected_image_ids[:max_images]

    # Create mini dataset
    mini_images = [image_dict[img_id] for img_id in selected_image_ids]

    # Collect all annotations for selected images
    mini_annotations = []
    for img_id in selected_image_ids:
        for cat_id, anns in image_annotations[img_id].items():
            mini_annotations.extend(anns)

    # Create final mini COCO dataset
    mini = {
        "info": ann.get("info", {}),
        "licenses": ann.get("licenses", []),
        "images": mini_images,
        "annotations": mini_annotations,
        "categories": categories,
    }

    # Save to file
    out_path.write_text(json.dumps(mini))

    # Print final statistics
    print("\nMini dataset statistics:")
    print(f"Saved mini COCO to {out_path}")
    print(f"Total images: {len(mini_images)}")
    print(f"Total annotations: {len(mini_annotations)}")

    # Count images per category in mini dataset
    mini_category_counts = defaultdict(set)
    for ann in mini_annotations:
        mini_category_counts[ann["category_id"]].add(ann["image_id"])

    print("\nImages per category in mini dataset:")
    for cat_id, img_ids in sorted(mini_category_counts.items()):
        cat_name = category_dict[cat_id]["name"]
        print(f"  Category {cat_id} ({cat_name}): {len(img_ids)} images")

    # Calculate overlap statistics
    total_images = len(selected_image_ids)
    print(f"\nTotal unique images selected: {total_images}")
    print(f"Target: {images_per_class} images per category × {len(categories)} categories = "
          f"{images_per_class * len(categories)} images")


if __name__ == "__main__":
    root = Path("/content/drive/MyDrive/xai-stability-data/coco/annotations")
    ann_path = root / "instances_train2017.json"
    out_path = root / "instances_train2017_mini.json"

    # 700 images per class × 80 classes = 56,000 images
    make_coco_mini_balanced(
        ann_path=ann_path,
        out_path=out_path,
        images_per_class=700,
        random_seed=42
    )
# Out:
# Original dataset statistics:
# Total images: 118287
# Total categories: 80
#   Category 1 (person): 64115 images
#   Category 2 (bicycle): 3252 images
#   Category 3 (car): 12251 images
#   Category 4 (motorcycle): 3502 images
#   Category 5 (airplane): 2986 images
#   Category 6 (bus): 3952 images
#   Category 7 (train): 3588 images
#   Category 8 (truck): 6127 images
#   Category 9 (boat): 3025 images
#   Category 10 (traffic light): 4139 images
#   Category 11 (fire hydrant): 1711 images
#   Category 13 (stop sign): 1734 images
#   Category 14 (parking meter): 705 images
#   Category 15 (bench): 5570 images
#   Category 16 (bird): 3237 images
#   Category 17 (cat): 4114 images
#   Category 18 (dog): 4385 images
#   Category 19 (horse): 2941 images
#   Category 20 (sheep): 1529 images
#   Category 21 (cow): 1968 images
#   Category 22 (elephant): 2143 images
#   Category 23 (bear): 960 images
#   Category 24 (zebra): 1916 images
#   Category 25 (giraffe): 2546 images
#   Category 27 (backpack): 5528 images
#   Category 28 (umbrella): 3968 images
#   Category 31 (handbag): 6841 images
#   Category 32 (tie): 3810 images
#   Category 33 (suitcase): 2402 images
#   Category 34 (frisbee): 2184 images
#   Category 35 (skis): 3082 images
#   Category 36 (snowboard): 1654 images
#   Category 37 (sports ball): 4262 images
#   Category 38 (kite): 2261 images
#   Category 39 (baseball bat): 2506 images
#   Category 40 (baseball glove): 2629 images
#   Category 41 (skateboard): 3476 images
#   Category 42 (surfboard): 3486 images
#   Category 43 (tennis racket): 3394 images
#   Category 44 (bottle): 8501 images
#   Category 46 (wine glass): 2533 images
#   Category 47 (cup): 9189 images
#   Category 48 (fork): 3555 images
#   Category 49 (knife): 4326 images
#   Category 50 (spoon): 3529 images
#   Category 51 (bowl): 7111 images
#   Category 52 (banana): 2243 images
#   Category 53 (apple): 1586 images
#   Category 54 (sandwich): 2365 images
#   Category 55 (orange): 1699 images
#   Category 56 (broccoli): 1939 images
#   Category 57 (carrot): 1683 images
#   Category 58 (hot dog): 1222 images
#   Category 59 (pizza): 3166 images
#   Category 60 (donut): 1523 images
#   Category 61 (cake): 2925 images
#   Category 62 (chair): 12774 images
#   Category 63 (couch): 4423 images
#   Category 64 (potted plant): 4452 images
#   Category 65 (bed): 3682 images
#   Category 67 (dining table): 11837 images
#   Category 70 (toilet): 3353 images
#   Category 72 (tv): 4561 images
#   Category 73 (laptop): 3524 images
#   Category 74 (mouse): 1876 images
#   Category 75 (remote): 3076 images
#   Category 76 (keyboard): 2115 images
#   Category 77 (cell phone): 4803 images
#   Category 78 (microwave): 1547 images
#   Category 79 (oven): 2877 images
#   Category 80 (toaster): 217 images
#   Category 81 (sink): 4678 images
#   Category 82 (refrigerator): 2360 images
#   Category 84 (book): 5332 images
#   Category 85 (clock): 4659 images
#   Category 86 (vase): 3593 images
#   Category 87 (scissors): 947 images
#   Category 88 (teddy bear): 2140 images
#   Category 89 (hair drier): 189 images
#   Category 90 (toothbrush): 1007 images
# Selected 700 images for category 1 (person)
# Selected 700 images for category 2 (bicycle)
# Selected 700 images for category 3 (car)
# Selected 700 images for category 4 (motorcycle)
# Selected 700 images for category 5 (airplane)
# Selected 700 images for category 6 (bus)
# Selected 700 images for category 7 (train)
# Selected 700 images for category 8 (truck)
# Selected 700 images for category 9 (boat)
# Selected 700 images for category 10 (traffic light)
# Selected 700 images for category 11 (fire hydrant)
# Selected 700 images for category 13 (stop sign)
# Selected 700 images for category 14 (parking meter)
# Selected 700 images for category 15 (bench)
# Selected 700 images for category 16 (bird)
# Selected 700 images for category 17 (cat)
# Selected 700 images for category 18 (dog)
# Selected 700 images for category 19 (horse)
# Selected 700 images for category 20 (sheep)
# Selected 700 images for category 21 (cow)
# Selected 700 images for category 22 (elephant)
# Selected 700 images for category 23 (bear)
# Selected 700 images for category 24 (zebra)
# Selected 700 images for category 25 (giraffe)
# Selected 700 images for category 27 (backpack)
# Selected 700 images for category 28 (umbrella)
# Selected 700 images for category 31 (handbag)
# Selected 700 images for category 32 (tie)
# Selected 700 images for category 33 (suitcase)
# Selected 700 images for category 34 (frisbee)
# Selected 700 images for category 35 (skis)
# Selected 700 images for category 36 (snowboard)
# Selected 700 images for category 37 (sports ball)
# Selected 700 images for category 38 (kite)
# Selected 700 images for category 39 (baseball bat)
# Selected 700 images for category 40 (baseball glove)
# Selected 700 images for category 41 (skateboard)
# Selected 700 images for category 42 (surfboard)
# Selected 700 images for category 43 (tennis racket)
# Selected 700 images for category 44 (bottle)
# Selected 700 images for category 46 (wine glass)
# Selected 700 images for category 47 (cup)
# Selected 700 images for category 48 (fork)
# Selected 700 images for category 49 (knife)
# Selected 700 images for category 50 (spoon)
# Selected 700 images for category 51 (bowl)
# Selected 700 images for category 52 (banana)
# Selected 700 images for category 53 (apple)
# Selected 700 images for category 54 (sandwich)
# Selected 700 images for category 55 (orange)
# Selected 700 images for category 56 (broccoli)
# Selected 700 images for category 57 (carrot)
# Selected 700 images for category 58 (hot dog)
# Selected 700 images for category 59 (pizza)
# Selected 700 images for category 60 (donut)
# Selected 700 images for category 61 (cake)
# Selected 700 images for category 62 (chair)
# Selected 700 images for category 63 (couch)
# Selected 700 images for category 64 (potted plant)
# Selected 700 images for category 65 (bed)
# Selected 700 images for category 67 (dining table)
# Selected 700 images for category 70 (toilet)
# Selected 700 images for category 72 (tv)
# Selected 700 images for category 73 (laptop)
# Selected 700 images for category 74 (mouse)
# Selected 700 images for category 75 (remote)
# Selected 700 images for category 76 (keyboard)
# Selected 700 images for category 77 (cell phone)
# Selected 700 images for category 78 (microwave)
# Selected 700 images for category 79 (oven)
# Warning: Category 80 (toaster) has only 217 images, requested 700. Using all available.
# Selected 217 images for category 80 (toaster)
# Selected 700 images for category 81 (sink)
# Selected 700 images for category 82 (refrigerator)
# Selected 700 images for category 84 (book)
# Selected 700 images for category 85 (clock)
# Selected 700 images for category 86 (vase)
# Selected 700 images for category 87 (scissors)
# Selected 700 images for category 88 (teddy bear)
# Warning: Category 89 (hair drier) has only 189 images, requested 700. Using all available.
# Selected 189 images for category 89 (hair drier)
# Selected 700 images for category 90 (toothbrush)
#
# Mini dataset statistics:
# Saved mini COCO to /content/drive/MyDrive/xai-stability-data/coco/annotations/instances_train2017_mini.json
# Total images: 45628
# Total annotations: 395840
#
# Images per category in mini dataset:
#   Category 1 (person): 24710 images
#   Category 2 (bicycle): 1629 images
#   Category 3 (car): 5068 images
#   Category 4 (motorcycle): 1309 images
#   Category 5 (airplane): 877 images
#   Category 6 (bus): 1515 images
#   Category 7 (train): 1033 images
#   Category 8 (truck): 2379 images
#   Category 9 (boat): 1107 images
#   Category 10 (traffic light): 1647 images
#   Category 11 (fire hydrant): 910 images
#   Category 13 (stop sign): 884 images
#   Category 14 (parking meter): 701 images
#   Category 15 (bench): 2165 images
#   Category 16 (bird): 1130 images
#   Category 17 (cat): 1579 images
#   Category 18 (dog): 1766 images
#   Category 19 (horse): 955 images
#   Category 20 (sheep): 771 images
#   Category 21 (cow): 842 images
#   Category 22 (elephant): 817 images
#   Category 23 (bear): 710 images
#   Category 24 (zebra): 770 images
#   Category 25 (giraffe): 820 images
#   Category 27 (backpack): 2591 images
#   Category 28 (umbrella): 1584 images
#   Category 31 (handbag): 3213 images
#   Category 32 (tie): 1426 images
#   Category 33 (suitcase): 1167 images
#   Category 34 (frisbee): 882 images
#   Category 35 (skis): 963 images
#   Category 36 (snowboard): 800 images
#   Category 37 (sports ball): 1761 images
#   Category 38 (kite): 880 images
#   Category 39 (baseball bat): 1229 images
#   Category 40 (baseball glove): 1247 images
#   Category 41 (skateboard): 1018 images
#   Category 42 (surfboard): 889 images
#   Category 43 (tennis racket): 1104 images
#   Category 44 (bottle): 4727 images
#   Category 46 (wine glass): 1579 images
#   Category 47 (cup): 5375 images
#   Category 48 (fork): 2216 images
#   Category 49 (knife): 2717 images
#   Category 50 (spoon): 2293 images
#   Category 51 (bowl): 4348 images
#   Category 52 (banana): 1267 images
#   Category 53 (apple): 1141 images
#   Category 54 (sandwich): 1406 images
#   Category 55 (orange): 1180 images
#   Category 56 (broccoli): 1104 images
#   Category 57 (carrot): 1156 images
#   Category 58 (hot dog): 831 images
#   Category 59 (pizza): 1430 images
#   Category 60 (donut): 884 images
#   Category 61 (cake): 1538 images
#   Category 62 (chair): 6479 images
#   Category 63 (couch): 2310 images
#   Category 64 (potted plant): 2362 images
#   Category 65 (bed): 1504 images
#   Category 67 (dining table): 6583 images
#   Category 70 (toilet): 1155 images
#   Category 72 (tv): 2633 images
#   Category 73 (laptop): 2038 images
#   Category 74 (mouse): 1340 images
#   Category 75 (remote): 1559 images
#   Category 76 (keyboard): 1457 images
#   Category 77 (cell phone): 2076 images
#   Category 78 (microwave): 1156 images
#   Category 79 (oven): 1821 images
#   Category 80 (toaster): 217 images
#   Category 81 (sink): 2495 images
#   Category 82 (refrigerator): 1523 images
#   Category 84 (book): 2985 images
#   Category 85 (clock): 1715 images
#   Category 86 (vase): 1788 images
#   Category 87 (scissors): 763 images
#   Category 88 (teddy bear): 1004 images
#   Category 89 (hair drier): 189 images
#   Category 90 (toothbrush): 752 images
#
# Total unique images selected: 45628
# Target: 700 images per category × 80 categories = 56000 images
